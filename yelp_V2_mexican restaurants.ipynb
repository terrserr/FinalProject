# %%
import requests
from pprint import pprint
import pandas as pd
import numpy as np
import requests
import json
from config import yelp_key_1, yelp_key_2, yelp_key_3, yelp_key_4, yelp_key_5
from yelpapi import YelpAPI

# %%
num_mexican_list_1 =[]
zip_code_list_1 = []
num_mexican_list_1b =[]
zip_code_list_1b = []
num_mexican_list_2 =[]
zip_code_list_2 = []
num_mexican_list_3 =[]
zip_code_list_3 = []
num_mexican_list_4 =[]
zip_code_list_4 = []
num_mexican_list_5 =[]
zip_code_list_5 = []

# %%
zip_df = pd.read_csv("Merged_V3.csv")
zip_df.head()
# Out:
#    Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 0           0              1072      1001          31603     0
# 1           1              2673      1002          14855     0
# 2           2              1528      1003           3973     0
# 3           3               310      1005          33312     0
# 4           4               821      1007          40089     0

# %%
zip_df_1 = zip_df.iloc[0:2302, 0:5]
zip_df_1.tail()
# Out:
#       Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 2297        2297               118      8887          49444     0
# 2298        2298               534      8889          59481     0
# 2299        2299              4673      8901          19290     1
# 2300        2300              2904      8902          39979     1
# 2301        2301              1184      8904          39643     0

# %%
zip_df_1b = zip_df.iloc[2302:4000, 0:5]
zip_df_1b.head()
# Out:
#       Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 2302        2302              1507     10001          60412     0
# 2303        2303              4074     10002          19311     0
# 2304        2304              3585     10003          65568     0
# 2305        2305               249     10004         101932     1
# 2306        2306               421     10005          86143     0

# %%
zip_df_2 = zip_df.iloc[4000:8000, 0:5]
zip_df_2.head()
# Out:
#       Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 4000        4000              3453     15068          27563     0
# 4001        4001              1146     15071          37410     0
# 4002        4002              1002     15074          27896     0
# 4003        4003                51     15076          21699     0
# 4004        4004                56     15077          14911     0

# %%
zip_df_3 = zip_df.iloc[8000:12000, 0:5]
zip_df_3.head()
# Out:
#       Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 8000        8000               293     28318          25289     0
# 8001        8001               609     28320          22985     0
# 8002        8002               421     28323          24821     0
# 8003        8003               107     28325          18800     0
# 8004        8004              1176     28326          29770     0

# %%
zip_df_4 = zip_df.iloc[12000:16000, 0:5]
zip_df_4.head()
# Out:
#        Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 12000       12000                32     40070          31477     0
# 12001       12001              1301     40071          31546     0
# 12002       12002               108     40075          27981     0
# 12003       12003               199     40076          25865     0
# 12004       12004                46     40077          26500     0

# %%
zip_df_5 = zip_df.iloc[16000:20738, 0:5]
zip_df_5.tail()
# Out:
#        Unnamed: 0  Total Population  ZIP Code  Median Income  Has?
# 20733       20733              1522     99835          36712     0
# 20734       20734                20     99836          32679     0
# 20735       20735               503     99840          36523     0
# 20736       20736                36     99841          33068     0
# 20737       20737               155     99922          15417     0

# %%
#testing our api call
yelp_api = YelpAPI(yelp_key_1)
search_results = yelp_api.search_query(term="mexican restaurant", location="75002")

# %%
pprint(search_results)
# Out:
# {'businesses': [{'alias': 'jhonnys-mexican-restaurant-st-paul',
#                  'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#                                 {'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 33.0522269923054,
#                                  'longitude': -96.5681216406885},
#                  'display_phone': '(469) 910-8766',
#                  'distance': 5284.03543011994,
#                  'id': 'lHZgqa76h8INikzRhRlqYA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/86Gf-4jzLE9H_1BE_mko9w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3999 Parker Rd',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'St Paul',
# ...

# %%
print(search_results['total'])
# Out:
# 489

# %%
# use iterrows to iterate through pandas dataframe and find #of fastfood
for index, row in zip_df_1.iterrows():

    # get restaurant type from df
    place = "0" + str(row['ZIP Code'])

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="mexican", location=place)
        print(f"The amount of mexican restaurants in {place} is {response['total']}.")
        num_mexican_list_1.append(response["total"])
        zip_code_list_1.append(place)
        
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 0: 01001.
# The amount of mexican restaurants in 01001 is 30.
# ------------
# Retrieving Results for Index 1: 01002.
# The amount of mexican restaurants in 01002 is 33.
# ------------
# Retrieving Results for Index 2: 01003.
# The amount of mexican restaurants in 01003 is 14.
# ------------
# Retrieving Results for Index 3: 01005.
# The amount of mexican restaurants in 01005 is 632.
# ------------
# Retrieving Results for Index 4: 01007.
# The amount of mexican restaurants in 01007 is 97.
# ------------
# Retrieving Results for Index 5: 01008.
# The amount of mexican restaurants in 01008 is 5.
# ------------
# Retrieving Results for Index 6: 01010.
# The amount of mexican restaurants in 01010 is 7.
# ------------
# Retrieving Results for Index 7: 01011.
# The amount of mexican restaurants in 01011 is 88.
# ------------
# Retrieving Results for Index 8: 01012.
# The amount of mexican restaurants in 01012 is 234.
# ------------
# ...

# %%
print(len(num_mexican_list_1))
# Out:
# 2302

# %%
for index, row in zip_df_1b.iterrows():

    # get restaurant type from df
    place = row['ZIP Code']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="mexican", location=place)
        print(f"The amount of mexican restaurants in {place} is {response['total']}.")
        num_mexican_list_1b.append(response["total"])
        zip_code_list_1b.append(place)
        
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 2302: 10001.
# The amount of mexican restaurants in 10001 is 805.
# ------------
# Retrieving Results for Index 2303: 10002.
# The amount of mexican restaurants in 10002 is 619.
# ------------
# Retrieving Results for Index 2304: 10003.
# The amount of mexican restaurants in 10003 is 821.
# ------------
# Retrieving Results for Index 2305: 10004.
# The amount of mexican restaurants in 10004 is 2500.
# ------------
# Retrieving Results for Index 2306: 10005.
# The amount of mexican restaurants in 10005 is 128.
# ------------
# Retrieving Results for Index 2307: 10006.
# The amount of mexican restaurants in 10006 is 134.
# ------------
# Retrieving Results for Index 2308: 10007.
# The amount of mexican restaurants in 10007 is 190.
# ------------
# Retrieving Results for Index 2309: 10009.
# The amount of mexican restaurants in 10009 is 751.
# ------------
# Retrieving Results for Index 2310: 10010.
# The amount of mexican restaurants in 10010 is 937.
# ...

# %%
yelp_api = YelpAPI(yelp_key_2)
for index, row in zip_df_2.iterrows():

    # get restaurant type from df
    place = row['ZIP Code']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="mexican", location=place)
        print(f"The amount of mexican restaurants in {place} is {response['total']}.")
        num_mexican_list_2.append(response["total"])
        zip_code_list_2.append(place)
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 4000: 15068.
# The amount of mexican restaurants in 15068 is 45.
# ------------
# Retrieving Results for Index 4001: 15071.
# The amount of mexican restaurants in 15071 is 149.
# ------------
# Retrieving Results for Index 4002: 15074.
# The amount of mexican restaurants in 15074 is 32.
# ------------
# Retrieving Results for Index 4003: 15076.
# The amount of mexican restaurants in 15076 is 61.
# ------------
# Retrieving Results for Index 4004: 15077.
# The amount of mexican restaurants in 15077 is 14.
# ------------
# Retrieving Results for Index 4005: 15078.
# The amount of mexican restaurants in 15078 is 199.
# ------------
# Retrieving Results for Index 4006: 15081.
# The amount of mexican restaurants in 15081 is 7.
# ------------
# Retrieving Results for Index 4007: 15083.
# The amount of mexican restaurants in 15083 is 6.
# ------------
# Retrieving Results for Index 4008: 15084.
# The amount of mexican restaurants in 15084 is 43.
# ------------
# ...

# %%
print(len(num_mexican_list_2))
# Out:
# 4000

# %%
yelp_api = YelpAPI(yelp_key_3)
for index, row in zip_df_3.iterrows():

    # get restaurant type from df
    place = row['ZIP Code']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="mexican", location=place)
        print(f"The amount of mexican restaurants in {place} is {response['total']}.")
        num_mexican_list_3.append(response["total"])
        zip_code_list_3.append(place)
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 8000: 28318.
# The amount of mexican restaurants in 28318 is 80.
# ------------
# Retrieving Results for Index 8001: 28320.
# The amount of mexican restaurants in 28320 is 23.
# ------------
# Retrieving Results for Index 8002: 28323.
# The amount of mexican restaurants in 28323 is 124.
# ------------
# Retrieving Results for Index 8003: 28325.
# The amount of mexican restaurants in 28325 is 34.
# ------------
# Retrieving Results for Index 8004: 28326.
# The amount of mexican restaurants in 28326 is 120.
# ------------
# Retrieving Results for Index 8005: 28327.
# The amount of mexican restaurants in 28327 is 50.
# ------------
# Retrieving Results for Index 8006: 28328.
# The amount of mexican restaurants in 28328 is 209.
# ------------
# Retrieving Results for Index 8007: 28332.
# The amount of mexican restaurants in 28332 is 29.
# ------------
# Retrieving Results for Index 8008: 28333.
# The amount of mexican restaurants in 28333 is 20.
# ...

# %%
print(len(num_mexican_list_3))
# Out:
# 3999

# %%
yelp_api = YelpAPI(yelp_key_4)
for index, row in zip_df_4.iterrows():

    # get restaurant type from df
    place = row['ZIP Code']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="mexican", location=place)
        print(f"The amount of mexican restaurants in {place} is {response['total']}.")
        num_mexican_list_4.append(response["total"])
        zip_code_list_4.append(place)
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 12000: 40070.
# The amount of mexican restaurants in 40070 is 7.
# ------------
# Retrieving Results for Index 12001: 40071.
# The amount of mexican restaurants in 40071 is 322.
# ------------
# Retrieving Results for Index 12002: 40075.
# The amount of mexican restaurants in 40075 is 802.
# ------------
# Retrieving Results for Index 12003: 40076.
# The amount of mexican restaurants in 40076 is 66.
# ------------
# Retrieving Results for Index 12004: 40077.
# The amount of mexican restaurants in 40077 is 313.
# ------------
# Retrieving Results for Index 12005: 40078.
# The amount of mexican restaurants in 40078 is 39.
# ------------
# Retrieving Results for Index 12006: 40104.
# The amount of mexican restaurants in 40104 is 18.
# ------------
# Retrieving Results for Index 12007: 40107.
# The amount of mexican restaurants in 40107 is 50.
# ------------
# Retrieving Results for Index 12008: 40108.
# The amount of mexican restaurants in 40108 is 97.
# ...

# %%
print(len(num_mexican_list_4))
# Out:
# 3999

# %%
yelp_api = YelpAPI(yelp_key_5)
for index, row in zip_df_5.iterrows():

    # get restaurant type from df
    place = row['ZIP Code']

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {place}.")
    
    
    
    try:
        response = yelp_api.search_query(term="mexican", location=place)
        print(f"The amount of mexican restaurants in {place} is {response['total']}.")
        num_mexican_list_5.append(response["total"])
        zip_code_list_5.append(place)
    except (Exception):
            print("Missing field/result... skipping.")
    print("------------")
# Out:
# Retrieving Results for Index 16000: 61773.
# The amount of mexican restaurants in 61773 is 180.
# ------------
# Retrieving Results for Index 16001: 61777.
# The amount of mexican restaurants in 61777 is 59.
# ------------
# Retrieving Results for Index 16002: 61778.
# The amount of mexican restaurants in 61778 is 206.
# ------------
# Retrieving Results for Index 16003: 61802.
# The amount of mexican restaurants in 61802 is 67.
# ------------
# Retrieving Results for Index 16004: 61810.
# The amount of mexican restaurants in 61810 is 138.
# ------------
# Retrieving Results for Index 16005: 61811.
# The amount of mexican restaurants in 61811 is 14.
# ------------
# Retrieving Results for Index 16006: 61814.
# The amount of mexican restaurants in 61814 is 9.
# ------------
# Retrieving Results for Index 16007: 61840.
# The amount of mexican restaurants in 61840 is 72.
# ------------
# Retrieving Results for Index 16008: 61843.
# The amount of mexican restaurants in 61843 is 5.
# ...

# %%
yelp_results_mex_df = pd.DataFrame({
    "zip code":zip_code_list_1 + zip_code_list_1b + zip_code_list_2 + zip_code_list_3 + zip_code_list_4 + zip_code_list_5,
    "num_of_fast_food":num_mexican_list_1 + num_mexican_list_1b + num_mexican_list_2 + num_mexican_list_3 + num_mexican_list_4 + num_mexican_list_5
})

# %%
yelp_results_mex_df.head()
# Out:
#   zip code  num_of_fast_food
# 0    01001                30
# 1    01002                33
# 2    01003                14
# 3    01005               632
# 4    01007                97

# %%
yelp_results_mex_df.to_csv('C:/Users/Teresa Barajas/Anaconda/Anaconda3/envs/API/FinalProject/yelp_results_mex.csv')
